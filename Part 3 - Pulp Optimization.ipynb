# %%
import csv
import pandas as pd
import numpy as np
from patsy import dmatrices
from pulp import *
import matplotlib.pyplot as plt


from sklearn.pipeline import Pipeline
from sklearn.linear_model import Ridge
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import Normalizer
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder


from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
#from sklearn.metrics import mean_poisson_deviance
from sklearn.model_selection import cross_val_score

import seaborn as sns
from sklearn.cluster import KMeans

import statsmodels.api as sm

calcio_A = pd.read_pickle("calcio_A.pk1")
calcio_C = pd.read_pickle("calcio_C.pk1")
calcio_D = pd.read_pickle("calcio_D.pk1")
calcio = pd.read_pickle("calcio.pk1")

# %% [markdown]
# # Part 3: Pulp Optimization
#
# Now we have assigned each player to a cluster, we can begin looking into using the PuLP optimizer to determine which combination of player tiers will get us the highest points total.
#
# First, we need to wrangle the data some more. We start by dropping players with value below 0 to avoid confusing the algorithm. (We won't miss them as they are technically the worst buys)
#
# There are many columns we don't need any more and these are dropped using the pop method. We also reindex the dataframe to avoid any indexing errors during processing the optimization algorithm.

# %%
calcio = calcio.loc[calcio["21/22_Value"] > 0]

dict = calcio.set_index("Nome").T.to_dict("index")
calcio = calcio.reset_index(drop=True)

keys_to_remove = ["Id", "Squadra", "Pg", "Mv", "Mf", "Gf", "Gs", "Rp", "Rc", "R+", "R-", "Ass", "Asf", "Amm", "Esp", "Unnamed: 18",
                 "IV","Au", "FV", "D", "BID", "ln(Bid)", "FV 19/20", "scaled_bid", "y_hat", "z_hat", "20/21_Value", "residual", "cluster"]

for i in keys_to_remove:
    
    dict.pop(i)

    calcio = calcio.drop(columns = i)
    

calcio = calcio.dropna()

newindex = []
for i in range(calcio.shape[0]):
    newindex.append(i)
    

calcio = pd.merge(pd.DataFrame(newindex), calcio, how='left', left_index = True, right_index = True)

pd.set_option('display.max_rows', 1000)

print(calcio)
# Out:
#        0  index  R              Nome  FV 20/21  2 YR AVG  21/22_Value Tier
# 0      0     16  A           BERARDI      8.37  8.196608   197.522789  Hig
# 1      1      1  A            LUKAKU      8.89  8.703271   261.110957  Hig
# 2      2      3  A         ZAPATA D.      7.88  8.139945   190.411280  Hig
# 3      3      0  A           RONALDO      8.79  8.969938   294.578695  Hig
# 4      4      8  A            CAPUTO      7.65  7.869946   156.525444  Hig
# 5      5      2  A          IMMOBILE      7.70  8.296612   210.073667  Hig
# 6      6     15  A            MURIEL      8.92  8.606605   248.978907  Hig
# 7      7      4  A       IBRAHIMOVIC      8.28  8.243275   203.379698  Hig
# 8      8     30  A          LAPADULA      6.50  6.756621    16.798818  Low
# 9      9     18  A              BOGA      6.46  6.709955    10.942007  Low
# 10    10     21  A       RAFAEL LEAO      6.78  6.779953    19.727027  Low
# 11    11     23  A          ORSOLINI      6.74  6.723286    12.615179  Low
# 12    12     13  A        JOAO PEDRO      7.41  7.439948   102.559019  Mid
# 13    13     11  A           MERTENS      7.37  7.299948    84.988526  Mid
# 14    14      9  A            BARROW      6.76  6.933286    38.970949  Mid
# 15    15      5  A       MARTINEZ L.      7.87  7.676612   132.261223  Mid
# 16    16     10  A             REBIC      7.44  7.559948   117.619444  Mid
# 17    17     24  A      QUAGLIARELLA      7.28  7.199949    72.438220  Mid
# 18    18     19  A           SANCHEZ      7.34  7.393282    96.702230  Mid
# 19    19     17  A            CORREA      6.91  6.983285    45.246023  Mid
# 20    20     27  A           CAICEDO      7.21  7.093283    59.051208  Mid
# 21    21     12  A           INSIGNE      8.21  7.783276   145.648032  Mid
# 22    22      7  A           BELOTTI      7.60  7.536614   114.690903  Mid
# 23    23     31  A            LOZANO      7.34  7.026616    50.684194  Mid
# 24    24      6  A             DZEKO      6.76  7.176619    69.510191  Mid
# 25    25     34  A           PETAGNA      7.09  6.966617    43.154158  Mid
# 26    26     32  A            PANDEV      6.79  6.923286    37.715889  Mid
# 27    27     58  C            JANKTO      6.47  6.379955    27.273419  Mid
# 28    28     48  C              RUIZ      6.30  6.329956    23.954363  Mid
# 29    29     77  C       TRAORE' HJ.      6.58  6.546621    38.337120  Mid
# 30    30     45  C             SENSI      5.91  6.286625    21.077944  Mid
# 31    31     55  C         LOCATELLI      6.53  6.409954    29.264869  Mid
# 32    32     50  C           BARELLA      6.61  6.436621    31.035036  Mid
# 33    33     57  C          ZACCAGNI      6.79  6.646619    44.975283  Mid
# 34    34     67  C       BONAVENTURA      6.30  6.406622    29.043685  Mid
# 35    35     49  C             KUCKA      6.79  6.749953    51.834805  Mid
# 36    36     36  C        KULUSEVSKI      6.43  6.763288    52.720048  Mid
# 37    37     52  C           LAZOVIC      6.58  6.576621    40.328594  Mid
# 38    38     61  C    PELLEGRINI LO.      6.94  6.793285    54.711319  Mid
# 39    39     46  C       CASTROVILLI      6.39  6.436622    31.035124  Mid
# 40    40     54  C           LAZZARI      6.34  6.279956    20.635223  Mid
# 41    41     44  C          POLITANO      7.01  6.763285    52.719817  Mid
# 42    42     59  C            NANDEZ      6.23  6.263290    19.528893  Mid
# 43    43     64  C          BROZOVIC      6.38  6.446622    31.698952  Mid
# 44    44     47  C           ERIKSEN      6.54  6.463288    32.805263  Mid
# 45    45     65  C          DJURICIC      6.52  6.579954    40.549893  Mid
# 46    46     70  C        NAINGGOLAN      6.09  6.456624    32.362893  Mid
# 47    47     53  C           KESSIE'      7.36  6.939949    64.447247  Hig
# 48    48     39  C      LUIS ALBERTO      7.03  7.123284    76.617498  Hig
# 49    49     68  C           SORIANO      6.97  6.853285    58.694255  Hig
# 50    50     40  C       MALINOVSKYI      7.44  7.263281    85.910881  Hig
# 51    51     66  C         ZIELINSKI      7.28  6.913283    62.677080  Hig
# 52    52     35  C        MKHITARYAN      7.74  7.689946   114.233948  Hig
# 53    53     42  C           DE PAUL      7.43  7.273281    86.574709  Hig
# 54    54     62  C          VERETOUT      7.36  7.156615    78.830116  Hig
# 55    55     43  C           PASALIC      7.00  6.959951    65.775040  Hig
# 56    56     38  C        CALHANOGLU      6.85  6.979952    67.102749  Hig
# 57    57     37  C  MILINKOVIC-SAVIC      7.20  7.039950    71.085558  Hig
# 58    58     41  C            CHIESA      7.43  7.336615    90.778933  Hig
# 59    59     63  C             VERDI      5.91  6.006625     2.490853  Low
# 60    60     73  C      SAELEMAEKERS      6.14  6.119957    10.014108  Low
# 61    61     51  C            RABIOT      6.09  6.036624     4.482255  Low
# 62    62     69  C        CASTILLEJO      5.92  6.149958    12.005670  Low
# 63    63     72  C            PULGAR      5.90  6.146625    11.784403  Low
# 64    64     71  C         BENTANCUR      5.92  6.016625     3.154674  Low
# 65    65     75  C           MARUSIC      5.94  6.139958    11.341837  Low
# 66    66     90  D          HATEBOER      6.41  6.223289    19.541799  Mid
# 67    67     99  D             TOLOI      5.97  6.096625    16.835455  Mid
# 68    68     88  D             YOUNG      6.14  6.436623    24.099983  Mid
# 69    69    102  D            DANILO      6.41  6.256622    20.254010  Mid
# 70    70     92  D           FARAONI      6.46  6.476621    24.954595  Mid
# 71    71    121  D    STRYGER LARSEN      5.98  6.043291    15.695916  Mid
# 72    72     84  D        SPINAZZOLA      6.52  6.489954    25.239471  Mid
# 73    73    103  D             KJAER      6.25  6.133290    17.618851  Mid
# 74    74     96  D        DI LORENZO      6.15  6.156624    18.117411  Mid
# 75    75     82  D           BONUCCI      6.16  6.239957    19.897937  Mid
# 76    76    125  D          SKRINIAR      6.58  6.366621    22.604284  Mid
# 77    77     86  D            ACERBI      5.94  6.103292    16.977901  Mid
# 78    78    116  D            ROMERO      6.44  6.209955    19.256911  Mid
# 79    79     97  D          DJIMSITI      6.03  6.089958    16.693005  Mid
# 80    80    114  D            MULDUR      5.96  6.079958    16.479351  Mid
# 81    81    127  D            BREMER      6.50  6.333288    21.892083  Mid
# 82    82    112  D           DEMIRAL      6.14  6.369957    22.675561  Mid
# 83    83    129  D           ANSALDI      6.33  6.393289    23.174084  Mid
# 84    84    124  D       ALEX SANDRO      6.23  6.176623    18.544727  Mid
# 85    85     93  D           BIRAGHI      6.03  6.163291    18.259869  Mid
# 86    86     85  D          CUADRADO      6.64  6.486620    25.168235  Mid
# 87    87    109  D          PALOMINO      6.05  6.049958    15.838349  Mid
# 88    88    110  D       BRUNO PERES      5.94  6.116625    17.262785  Mid
# 89    89    126  D           MANCINI      6.41  6.233289    19.755462  Mid
# 90    90     94  D         CHIELLINI      5.91  6.233292    19.755526  Mid
# 91    91    119  D           DARMIAN      6.63  6.403287    23.387709  Mid
# 92    92     89  D           DE LIGT      6.30  6.326623    21.749667  Mid
# 93    93     81  D          CRISCITO      6.09  6.253291    20.182830  Mid
# 94    94     87  D        MILENKOVIC      5.97  6.133291    17.618887  Mid
# 95    95    106  D           MANOLAS      5.91  6.079958    16.479357  Mid
# 96    96     83  D           DE VRIJ      6.28  6.386623    23.031649  Mid
# 97    97    111  D          KUMBULLA      5.84  5.933292    13.345639  Low
# 98    98    107  D      RODRIGUEZ R.      5.38  5.519962     4.514284  Low
# 99    99    113  D              IZZO      6.14  6.006624    14.912464  Low
# 100  100    123  D              RADU      5.88  5.886626    12.348538  Low
# 101  101    128  D       BERESZYNSKI      5.90  5.683292     8.004050  Low
# 102  102     95  D         KOULIBALY      5.98  5.859958    11.778757  Low
# 103  103     98  D             GODIN      5.95  6.003292    14.841267  Low
# 104  104    122  D             HYSAJ      5.93  5.969958    14.129059  Low
# 105  105    118  D        MAKSIMOVIC      5.29  5.526629     4.656738  Low
# 106  106    105  D          N'KOULOU      5.67  5.709960     8.573848  Low
# 107  107     91  D           KOLAROV      5.38  5.759962     9.642202  Low
# 108  108    115  D          TOMIYASU      6.00  5.966625    14.057829  Low
# 109  109    104  D           CALDARA      5.75  5.769960     9.855817  Low
# 110  110    100  D     PEZZELLA GER.      5.77  5.899959    12.633437  Low
# 111  111    117  D           MALCUIT      5.70  5.799960    10.496813  Low
# 112  112    101  D         MARIO RUI      5.90  5.846625    11.493883  Low
# 113  113    108  D          GAGLIOLO      5.81  5.963293    13.986632  Low
# 114  114     79  D            GOSENS      7.28  7.313282    42.830980  Hig
# 115  115    120  D        D'AMBROSIO      7.12  6.939950    34.854240  Hig
# 116  116     80  D      HERNANDEZ T.      6.86  6.816619    32.219093  Hig

# %% [markdown]
# Above we can see our simplified dataframe that is ready to be optimized.
#
# There is just one more thing to do which is one-hot encode the "R" column which is the position of the player (A, C or D). We will see later why this is important but it is in relation the way one of the constraints is written for the optimization.

# %%
dummies = pd.get_dummies(calcio["R"])


calcio = pd.merge(calcio, dummies, how='right', left_index = True, right_index = True)

# %% [markdown]
# Now our data is ready for the optimization. We create the pulp problem, calling it the "PointsMaximizer" and we define the problem as a maximization problem. Now we have to create our decision variables, and for each player we append the Name, position and tier. In the line below, we define each value as binary: they can only be either 1 or 0- they can only be in the team or not.

# %%
prob = pulp.LpProblem('PointsMaximizer', LpMaximize)

decision_variables = []

for rownum, row in calcio.iterrows():
    variable = str('x' + str(row["Nome"])+str(row["R"])+str(row["Tier"]))
    variable = pulp.LpVariable(str(variable), lowBound = 0, upBound = 1, cat= 'Integer') #make variables binary
    decision_variables.append(variable)
    
print ("Total number of decision_variables: " + str(len(decision_variables)))
print ("Array with Decision Variables:" + str(decision_variables))
# Out:
# Total number of decision_variables: 117
# Array with Decision Variables:[xBERARDIAHig, xLUKAKUAHig, xZAPATA_D.AHig, xRONALDOAHig, xCAPUTOAHig, xIMMOBILEAHig, xMURIELAHig, xIBRAHIMOVICAHig, xLAPADULAALow, xBOGAALow, xRAFAEL_LEAOALow, xORSOLINIALow, xJOAO_PEDROAMid, xMERTENSAMid, xBARROWAMid, xMARTINEZ_L.AMid, xREBICAMid, xQUAGLIARELLAAMid, xSANCHEZAMid, xCORREAAMid, xCAICEDOAMid, xINSIGNEAMid, xBELOTTIAMid, xLOZANOAMid, xDZEKOAMid, xPETAGNAAMid, xPANDEVAMid, xJANKTOCMid, xRUIZCMid, xTRAORE'_HJ.CMid, xSENSICMid, xLOCATELLICMid, xBARELLACMid, xZACCAGNICMid, xBONAVENTURACMid, xKUCKACMid, xKULUSEVSKICMid, xLAZOVICCMid, xPELLEGRINI_LO.CMid, xCASTROVILLICMid, xLAZZARICMid, xPOLITANOCMid, xNANDEZCMid, xBROZOVICCMid, xERIKSENCMid, xDJURICICCMid, xNAINGGOLANCMid, xKESSIE'CHig, xLUIS_ALBERTOCHig, xSORIANOCHig, xMALINOVSKYICHig, xZIELINSKICHig, xMKHITARYANCHig, xDE_PAULCHig, xVERETOUTCHig, xPASALICCHig, xCALHANOGLUCHig, xMILINKOVIC_SAVICCHig, xCHIESACHig, xVERDICLow, xSAELEMAEKERSCLow, xRABIOTCLow, xCASTILLEJOCLow, xPULGARCLow, xBENTANCURCLow, xMARUSICCLow, xHATEBOERDMid, xTOLOIDMid, xYOUNGDMid, xDANILODMid, xFARAONIDMid, xSTRYGER_LARSENDMid, xSPINAZZOLADMid, xKJAERDMid, xDI_LORENZODMid, xBONUCCIDMid, xSKRINIARDMid, xACERBIDMid, xROMERODMid, xDJIMSITIDMid, xMULDURDMid, xBREMERDMid, xDEMIRALDMid, xANSALDIDMid, xALEX_SANDRODMid, xBIRAGHIDMid, xCUADRADODMid, xPALOMINODMid, xBRUNO_PERESDMid, xMANCINIDMid, xCHIELLINIDMid, xDARMIANDMid, xDE_LIGTDMid, xCRISCITODMid, xMILENKOVICDMid, xMANOLASDMid, xDE_VRIJDMid, xKUMBULLADLow, xRODRIGUEZ_R.DLow, xIZZODLow, xRADUDLow, xBERESZYNSKIDLow, xKOULIBALYDLow, xGODINDLow, xHYSAJDLow, xMAKSIMOVICDLow, xN'KOULOUDLow, xKOLAROVDLow, xTOMIYASUDLow, xCALDARADLow, xPEZZELLA_GER.DLow, xMALCUITDLow, xMARIO_RUIDLow, xGAGLIOLODLow, xGOSENSDHig, xD'AMBROSIODHig, xHERNANDEZ_T.DHig]

# %% [markdown]
# Now we define the total_points formula, which is what we will be optimizing. We iterate over the df and decision variable, and when the name matches up we multiply the decision variable by their 2 Year average.
#
# This creates the optimization formula, which then gets added to the PuLP problem.

# %%
total_points = ""



for i, schedule in enumerate(decision_variables):
    for rownum, row in calcio.iterrows():
        if rownum  == i:
                   
                      
            formula = row["2 YR AVG"]*schedule
                 
            total_points = lpSum([total_points, formula])
        
            
            
prob += total_points
print ("Optimization function: " + str(total_points))
# Out:
# Optimization function: 6.10329159*xACERBIDMid + 6.17662311*xALEX_SANDRODMid + 6.39328896*xANSALDIDMid + 6.43662057*xBARELLACMid + 6.93328584*xBARROWAMid + 7.53661353*xBELOTTIAMid + 6.01662513*xBENTANCURCLow + 8.19660825*xBERARDIAHig + 5.68329225*xBERESZYNSKIDLow + 6.16329099*xBIRAGHIDMid + 6.70995453*xBOGAALow + 6.40662246*xBONAVENTURACMid + 6.2399568*xBONUCCIDMid + 6.333288*xBREMERDMid + 6.44662194*xBROZOVICCMid + 6.11662491*xBRUNO_PERESDMid + 7.09328298*xCAICEDOAMid + 5.76995973*xCALDARADLow + 6.97995192*xCALHANOGLUCHig + 7.86994623*xCAPUTOAHig + 6.14995833*xCASTILLEJOCLow + 6.43662189*xCASTROVILLICMid + 6.23329164*xCHIELLINIDMid + 7.33661475*xCHIESACHig + 6.98328489*xCORREAAMid + 6.25329054*xCRISCITODMid + 6.48662034*xCUADRADODMid + 6.93995034*xD'AMBROSIODHig + 6.25662195*xDANILODMid + 6.40328715*xDARMIANDMid + 6.36995679*xDEMIRALDMid + 6.32662254*xDE_LIGTDMid + 7.27328148*xDE_PAULCHig + 6.3866226*xDE_VRIJDMid + 6.15662361*xDI_LORENZODMid + 6.08995773*xDJIMSITIDMid + 6.579954300000001*xDJURICICCMid + 7.17661893*xDZEKOAMid + 6.46328763*xERIKSENCMid + 6.47662143*xFARAONIDMid + 5.96329251*xGAGLIOLODLow + 6.00329163*xGODINDLow + 7.31328234*xGOSENSDHig + 6.22328865*xHATEBOERDMid + 6.81661869*xHERNANDEZ_T.DHig + 5.96995845*xHYSAJDLow + 8.24327541*xIBRAHIMOVICAHig + 8.29661217*xIMMOBILEAHig + 7.78327629*xINSIGNEAMid + 6.00662382*xIZZODLow + 6.379954799999999*xJANKTOCMid + 7.4399481*xJOAO_PEDROAMid + 6.9399489*xKESSIE'CHig + 6.133289700000001*xKJAERDMid + 5.75996196*xKOLAROVDLow + 5.85995826*xKOULIBALYDLow + 6.74995251*xKUCKACMid + 6.76328799*xKULUSEVSKICMid + 5.93329236*xKUMBULLADLow + 6.75662091*xLAPADULAALow + 6.57662061*xLAZOVICCMid + 6.27995568*xLAZZARICMid + 6.40995441*xLOCATELLICMid + 7.0266156*xLOZANOAMid + 7.12328403*xLUIS_ALBERTOCHig + 8.70327129*xLUKAKUAHig + 5.5266294*xMAKSIMOVICDLow + 5.79996*xMALCUITDLow + 7.26328143*xMALINOVSKYICHig + 6.23328864*xMANCINIDMid + 6.07995846*xMANOLASDMid + 5.84662542*xMARIO_RUIDLow + 7.67661177*xMARTINEZ_L.AMid + 6.13995822*xMARUSICCLow + 7.29994848*xMERTENSAMid + 6.13329138*xMILENKOVICDMid + 7.03994976*xMILINKOVIC_SAVICCHig + 7.68994587*xMKHITARYANCHig + 6.07995816*xMULDURDMid + 8.60660454*xMURIELAHig + 5.70996027*xN'KOULOUDLow + 6.45662367*xNAINGGOLANCMid + 6.26328969*xNANDEZCMid + 6.72328617*xORSOLINIALow + 6.04995765*xPALOMINODMid + 6.92328567*xPANDEVAMid + 6.95995104*xPASALICCHig + 6.793284900000001*xPELLEGRINI_LO.CMid + 6.96661716*xPETAGNAAMid + 5.89995948*xPEZZELLA_GER.DLow + 6.76328451*xPOLITANOCMid + 6.14662512*xPULGARCLow + 7.19994912*xQUAGLIARELLAAMid + 6.03662409*xRABIOTCLow + 5.8866255*xRADUDLow + 6.77995254*xRAFAEL_LEAOALow + 7.559947800000001*xREBICAMid + 5.5199622*xRODRIGUEZ_R.DLow + 6.20995515*xROMERODMid + 8.96993829*xRONALDOAHig + 6.32995587*xRUIZCMid + 6.11995704*xSAELEMAEKERSCLow + 7.393281900000001*xSANCHEZAMid + 6.28662492*xSENSICMid + 6.36662082*xSKRINIARDMid + 6.85328466*xSORIANOCHig + 6.48995439*xSPINAZZOLADMid + 6.04329141*xSTRYGER_LARSENDMid + 6.09662475*xTOLOIDMid + 5.966624700000001*xTOMIYASUDLow + 6.54662064*xTRAORE'_HJ.CMid + 6.0066252*xVERDICLow + 7.15661535*xVERETOUTCHig + 6.43662339*xYOUNGDMid + 6.64661928*xZACCAGNICMid + 8.13994458*xZAPATA_D.AHig + 6.91328274*xZIELINSKICHig

# %% [markdown]
# Now we write a similar formula but this time we multiply the decision variable by the cost of the player. However we aren't trying to maximize this formula- this will be one our constraints. We want to keep the cumulative budget lower than the budget we set.
#
# I decided to only optimize the 10 starting positions, excluding the goal keeper. We set 100 of the 1000 credit budget aside for the keepers, and 100 aside for bench and reserve outfield players. These budgets can be adjusted but for now I settled with a budget of 700 for the outfield starting players.
#
# We add the constraint to the PuLP problem; that the total cumulative budget must be less or equal to than our set budget.

# %%
budget = 800
totalbudget = ""


for rownum, row in calcio.iterrows():
    for i, schedule in enumerate(decision_variables):
        if rownum == i:
            formula = row["21/22_Value"]*schedule
            totalbudget = lpSum([totalbudget, formula])
            

                
            
prob += (totalbudget <= budget)

# %% [markdown]
# Now we write our final constraints. These are in order to make the players chosen fit into the decided starting formation. If we weren't to do this we could end up with 10 Attackers, which is not a viable formation in the fantacalcio game.
#
# We iterate over the schedule again but this is where the one hot encoded position columns become useful. E.g row["A"] would give a 0 for every player that is not an attacker and they would not be included in the Attacking Player constraint.
#
# We set ourselves a formation of 4 3 3, and add these constraints to the problem. There is an argument for having the optimizer pick us a formation, but for now we just settled for the renowned 4 3 3, as the consensus is this is the strongest way to set up your squad, having 4 defenders in order to get the defenders bonus mentioned earlier, and 3 attackers getting the bulk of the goals.

# %%
Aplayers = ""
for rownum, row in calcio.iterrows():
    for i, schedule in enumerate(decision_variables):
        if rownum == i:
            formula = row["A"]*schedule
            Aplayers = formula + Aplayers

Cplayers = ""
for rownum, row in calcio.iterrows():
    for i, schedule in enumerate(decision_variables):
        if rownum == i:
            formula = row["C"]*schedule
            Cplayers = formula + Cplayers
            
Dplayers = ""
for rownum, row in calcio.iterrows():
    for i, schedule in enumerate(decision_variables):
        if rownum == i:
            formula = row["D"]*schedule
            Dplayers = formula + Dplayers
            



prob += (Aplayers == 3)
prob += (Cplayers == 3)
prob += (Dplayers == 4)

# %% [markdown]
# Now we can print our problem, and write it to an LP file. We can look at all our constraints below and make sure they all look correct according to what we are trying to achieve.

# %%
print(prob)
prob.writeLP("PointsMaximizer.lp")
# Out:
# PointsMaximizer:
# MAXIMIZE
# 6.10329159*xACERBIDMid + 6.17662311*xALEX_SANDRODMid + 6.39328896*xANSALDIDMid + 6.43662057*xBARELLACMid + 6.93328584*xBARROWAMid + 7.53661353*xBELOTTIAMid + 6.01662513*xBENTANCURCLow + 8.19660825*xBERARDIAHig + 5.68329225*xBERESZYNSKIDLow + 6.16329099*xBIRAGHIDMid + 6.70995453*xBOGAALow + 6.40662246*xBONAVENTURACMid + 6.2399568*xBONUCCIDMid + 6.333288*xBREMERDMid + 6.44662194*xBROZOVICCMid + 6.11662491*xBRUNO_PERESDMid + 7.09328298*xCAICEDOAMid + 5.76995973*xCALDARADLow + 6.97995192*xCALHANOGLUCHig + 7.86994623*xCAPUTOAHig + 6.14995833*xCASTILLEJOCLow + 6.43662189*xCASTROVILLICMid + 6.23329164*xCHIELLINIDMid + 7.33661475*xCHIESACHig + 6.98328489*xCORREAAMid + 6.25329054*xCRISCITODMid + 6.48662034*xCUADRADODMid + 6.93995034*xD'AMBROSIODHig + 6.25662195*xDANILODMid + 6.40328715*xDARMIANDMid + 6.36995679*xDEMIRALDMid + 6.32662254*xDE_LIGTDMid + 7.27328148*xDE_PAULCHig + 6.3866226*xDE_VRIJDMid + 6.15662361*xDI_LORENZODMid + 6.08995773*xDJIMSITIDMid + 6.579954300000001*xDJURICICCMid + 7.17661893*xDZEKOAMid + 6.46328763*xERIKSENCMid + 6.47662143*xFARAONIDMid + 5.96329251*xGAGLIOLODLow + 6.00329163*xGODINDLow + 7.31328234*xGOSENSDHig + 6.22328865*xHATEBOERDMid + 6.81661869*xHERNANDEZ_T.DHig + 5.96995845*xHYSAJDLow + 8.24327541*xIBRAHIMOVICAHig + 8.29661217*xIMMOBILEAHig + 7.78327629*xINSIGNEAMid + 6.00662382*xIZZODLow + 6.379954799999999*xJANKTOCMid + 7.4399481*xJOAO_PEDROAMid + 6.9399489*xKESSIE'CHig + 6.133289700000001*xKJAERDMid + 5.75996196*xKOLAROVDLow + 5.85995826*xKOULIBALYDLow + 6.74995251*xKUCKACMid + 6.76328799*xKULUSEVSKICMid + 5.93329236*xKUMBULLADLow + 6.75662091*xLAPADULAALow + 6.57662061*xLAZOVICCMid + 6.27995568*xLAZZARICMid + 6.40995441*xLOCATELLICMid + 7.0266156*xLOZANOAMid + 7.12328403*xLUIS_ALBERTOCHig + 8.70327129*xLUKAKUAHig + 5.5266294*xMAKSIMOVICDLow + 5.79996*xMALCUITDLow + 7.26328143*xMALINOVSKYICHig + 6.23328864*xMANCINIDMid + 6.07995846*xMANOLASDMid + 5.84662542*xMARIO_RUIDLow + 7.67661177*xMARTINEZ_L.AMid + 6.13995822*xMARUSICCLow + 7.29994848*xMERTENSAMid + 6.13329138*xMILENKOVICDMid + 7.03994976*xMILINKOVIC_SAVICCHig + 7.68994587*xMKHITARYANCHig + 6.07995816*xMULDURDMid + 8.60660454*xMURIELAHig + 5.70996027*xN'KOULOUDLow + 6.45662367*xNAINGGOLANCMid + 6.26328969*xNANDEZCMid + 6.72328617*xORSOLINIALow + 6.04995765*xPALOMINODMid + 6.92328567*xPANDEVAMid + 6.95995104*xPASALICCHig + 6.793284900000001*xPELLEGRINI_LO.CMid + 6.96661716*xPETAGNAAMid + 5.89995948*xPEZZELLA_GER.DLow + 6.76328451*xPOLITANOCMid + 6.14662512*xPULGARCLow + 7.19994912*xQUAGLIARELLAAMid + 6.03662409*xRABIOTCLow + 5.8866255*xRADUDLow + 6.77995254*xRAFAEL_LEAOALow + 7.559947800000001*xREBICAMid + 5.5199622*xRODRIGUEZ_R.DLow + 6.20995515*xROMERODMid + 8.96993829*xRONALDOAHig + 6.32995587*xRUIZCMid + 6.11995704*xSAELEMAEKERSCLow + 7.393281900000001*xSANCHEZAMid + 6.28662492*xSENSICMid + 6.36662082*xSKRINIARDMid + 6.85328466*xSORIANOCHig + 6.48995439*xSPINAZZOLADMid + 6.04329141*xSTRYGER_LARSENDMid + 6.09662475*xTOLOIDMid + 5.966624700000001*xTOMIYASUDLow + 6.54662064*xTRAORE'_HJ.CMid + 6.0066252*xVERDICLow + 7.15661535*xVERETOUTCHig + 6.43662339*xYOUNGDMid + 6.64661928*xZACCAGNICMid + 8.13994458*xZAPATA_D.AHig + 6.91328274*xZIELINSKICHig + 0.0
# SUBJECT TO
# _C1: 16.9779006558 xACERBIDMid + 18.5447271688 xALEX_SANDRODMid
#  + 23.1740843437 xANSALDIDMid + 31.035036121 xBARELLACMid
#  + 38.9709487137 xBARROWAMid + 114.690903481 xBELOTTIAMid
#  + 3.15467353338 xBENTANCURCLow + 197.522789326 xBERARDIAHig
#  + 8.00405010173 xBERESZYNSKIDLow + 18.2598685011 xBIRAGHIDMid
#  + 10.9420069434 xBOGAALow + 29.0436854917 xBONAVENTURACMid
#  + 19.8979366027 xBONUCCIDMid + 21.8920831669 xBREMERDMid
#  + 31.6989524292 xBROZOVICCMid + 17.2627849631 xBRUNO_PERESDMid
#  + 59.0512075921 xCAICEDOAMid + 9.85581732931 xCALDARADLow
#  + 67.1027492448 xCALHANOGLUCHig + 156.525444453 xCAPUTOAHig
#  + 12.005669537 xCASTILLEJOCLow + 31.035123746 xCASTROVILLICMid
#  + 19.7555264985 xCHIELLINIDMid + 90.7789325432 xCHIESACHig
#  + 45.2460225536 xCORREAAMid + 20.1828298839 xCRISCITODMid
#  + 25.1682347539 xCUADRADODMid + 34.8542396692 xD'AMBROSIODHig
#  + 20.2540099374 xDANILODMid + 23.3877091148 xDARMIANDMid
#  + 22.6755611635 xDEMIRALDMid + 21.7496666528 xDE_LIGTDMid
#  + 86.5747094415 xDE_PAULCHig + 23.0316485999 xDE_VRIJDMid
#  + 18.1174109636 xDI_LORENZODMid + 16.6930048106 xDJIMSITIDMid
#  + 40.5498926715 xDJURICICCMid + 69.5101911082 xDZEKOAMid
#  + 32.8052632024 xERIKSENCMid + 24.954594599 xFARAONIDMid
#  + 13.9866320942 xGAGLIOLODLow + 14.8412670686 xGODINDLow
#  + 42.8309797637 xGOSENSDHig + 19.541799169 xHATEBOERDMid
#  + 32.2190931575 xHERNANDEZ_T.DHig + 14.1290588641 xHYSAJDLow
#  + 203.379698105 xIBRAHIMOVICAHig + 210.073667439 xIMMOBILEAHig
#  + 145.648032318 xINSIGNEAMid + 14.9124637878 xIZZODLow
#  + 27.2734185808 xJANKTOCMid + 102.559018755 xJOAO_PEDROAMid
#  + 64.4472473132 xKESSIE'CHig + 17.618850606 xKJAERDMid
#  + 9.64220153207 xKOLAROVDLow + 11.7787569185 xKOULIBALYDLow
#  + 51.8348050363 xKUCKACMid + 52.720048023 xKULUSEVSKICMid
#  + 13.3456385567 xKUMBULLADLow + 16.7988178297 xLAPADULAALow
#  + 40.3285938737 xLAZOVICCMid + 20.6352233565 xLAZZARICMid
#  + 29.2648687839 xLOCATELLICMid + 50.6841939746 xLOZANOAMid
#  + 76.6174982556 xLUIS_ALBERTOCHig + 261.110957261 xLUKAKUAHig
#  + 4.65673769102 xMAKSIMOVICDLow + 10.4968134308 xMALCUITDLow
#  + 85.9108807583 xMALINOVSKYICHig + 19.7554623995 xMANCINIDMid
#  + 16.4793569638 xMANOLASDMid + 11.4938828669 xMARIO_RUIDLow
#  + 132.261223186 xMARTINEZ_L.AMid + 11.3418368708 xMARUSICCLow
#  + 84.9885258544 xMERTENSAMid + 17.6188865014 xMILENKOVICDMid
#  + 71.0855580431 xMILINKOVIC_SAVICCHig + 114.233948481 xMKHITARYANCHig
#  + 16.4793505539 xMULDURDMid + 248.978906869 xMURIELAHig
#  + 8.57384820201 xN'KOULOUDLow + 32.3628926351 xNAINGGOLANCMid
#  + 19.5288926685 xNANDEZCMid + 12.6151792419 xORSOLINIALow
#  + 15.8383493245 xPALOMINODMid + 37.7158887643 xPANDEVAMid
#  + 65.7750401 xPASALICCHig + 54.7113189932 xPELLEGRINI_LO.CMid
#  + 43.1541580783 xPETAGNAAMid + 12.6334367621 xPEZZELLA_GER.DLow
#  + 52.7198170117 xPOLITANOCMid + 11.7844026028 xPULGARCLow
#  + 72.4382200397 xQUAGLIARELLAAMid + 4.48225522373 xRABIOTCLow
#  + 12.348538353 xRADUDLow + 19.7270274868 xRAFAEL_LEAOALow
#  + 117.619444468 xREBICAMid + 4.51428399951 xRODRIGUEZ_R.DLow
#  + 19.2569110157 xROMERODMid + 294.578695461 xRONALDOAHig
#  + 23.9543627897 xRUIZCMid + 10.0141078112 xSAELEMAEKERSCLow
#  + 96.7022304595 xSANCHEZAMid + 21.0779444236 xSENSICMid
#  + 22.6042836795 xSKRINIARDMid + 58.694255246 xSORIANOCHig
#  + 25.2394712145 xSPINAZZOLADMid + 15.6959161447 xSTRYGER_LARSENDMid
#  + 16.8354546562 xTOLOIDMid + 14.0578288134 xTOMIYASUDLow
#  + 38.3371197728 xTRAORE'_HJ.CMid + 2.49085281606 xVERDICLow
#  + 78.830115819 xVERETOUTCHig + 24.0999827003 xYOUNGDMid
#  + 44.9752831335 xZACCAGNICMid + 190.411279942 xZAPATA_D.AHig
#  + 62.6770799761 xZIELINSKICHig <= 700
#
# _C2: xBARROWAMid + xBELOTTIAMid + xBERARDIAHig + xBOGAALow + xCAICEDOAMid
#  + xCAPUTOAHig + xCORREAAMid + xDZEKOAMid + xIBRAHIMOVICAHig + xIMMOBILEAHig
#  + xINSIGNEAMid + xJOAO_PEDROAMid + xLAPADULAALow + xLOZANOAMid + xLUKAKUAHig
#  + xMARTINEZ_L.AMid + xMERTENSAMid + xMURIELAHig + xORSOLINIALow + xPANDEVAMid
#  + xPETAGNAAMid + xQUAGLIARELLAAMid + xRAFAEL_LEAOALow + xREBICAMid
#  + xRONALDOAHig + xSANCHEZAMid + xZAPATA_D.AHig = 3
#
# _C3: xBARELLACMid + xBENTANCURCLow + xBONAVENTURACMid + xBROZOVICCMid
#  + xCALHANOGLUCHig + xCASTILLEJOCLow + xCASTROVILLICMid + xCHIESACHig
#  + xDE_PAULCHig + xDJURICICCMid + xERIKSENCMid + xJANKTOCMid + xKESSIE'CHig
#  + xKUCKACMid + xKULUSEVSKICMid + xLAZOVICCMid + xLAZZARICMid + xLOCATELLICMid
#  + xLUIS_ALBERTOCHig + xMALINOVSKYICHig + xMARUSICCLow + xMILINKOVIC_SAVICCHig
#  + xMKHITARYANCHig + xNAINGGOLANCMid + xNANDEZCMid + xPASALICCHig
#  + xPELLEGRINI_LO.CMid + xPOLITANOCMid + xPULGARCLow + xRABIOTCLow + xRUIZCMid
#  + xSAELEMAEKERSCLow + xSENSICMid + xSORIANOCHig + xTRAORE'_HJ.CMid
#  + xVERDICLow + xVERETOUTCHig + xZACCAGNICMid + xZIELINSKICHig = 3
#
# _C4: xACERBIDMid + xALEX_SANDRODMid + xANSALDIDMid + xBERESZYNSKIDLow
#  + xBIRAGHIDMid + xBONUCCIDMid + xBREMERDMid + xBRUNO_PERESDMid + xCALDARADLow
#  + xCHIELLINIDMid + xCRISCITODMid + xCUADRADODMid + xD'AMBROSIODHig
#  + xDANILODMid + xDARMIANDMid + xDEMIRALDMid + xDE_LIGTDMid + xDE_VRIJDMid
#  + xDI_LORENZODMid + xDJIMSITIDMid + xFARAONIDMid + xGAGLIOLODLow + xGODINDLow
#  + xGOSENSDHig + xHATEBOERDMid + xHERNANDEZ_T.DHig + xHYSAJDLow + xIZZODLow
#  + xKJAERDMid + xKOLAROVDLow + xKOULIBALYDLow + xKUMBULLADLow
#  + xMAKSIMOVICDLow + xMALCUITDLow + xMANCINIDMid + xMANOLASDMid
#  + xMARIO_RUIDLow + xMILENKOVICDMid + xMULDURDMid + xN'KOULOUDLow
#  + xPALOMINODMid + xPEZZELLA_GER.DLow + xRADUDLow + xRODRIGUEZ_R.DLow
#  + xROMERODMid + xSKRINIARDMid + xSPINAZZOLADMid + xSTRYGER_LARSENDMid
#  + xTOLOIDMid + xTOMIYASUDLow + xYOUNGDMid = 4
#
# VARIABLES
# 0 <= xACERBIDMid <= 1 Integer
# 0 <= xALEX_SANDRODMid <= 1 Integer
# 0 <= xANSALDIDMid <= 1 Integer
# 0 <= xBARELLACMid <= 1 Integer
# 0 <= xBARROWAMid <= 1 Integer
# 0 <= xBELOTTIAMid <= 1 Integer
# 0 <= xBENTANCURCLow <= 1 Integer
# 0 <= xBERARDIAHig <= 1 Integer
# 0 <= xBERESZYNSKIDLow <= 1 Integer
# 0 <= xBIRAGHIDMid <= 1 Integer
# 0 <= xBOGAALow <= 1 Integer
# 0 <= xBONAVENTURACMid <= 1 Integer
# 0 <= xBONUCCIDMid <= 1 Integer
# 0 <= xBREMERDMid <= 1 Integer
# 0 <= xBROZOVICCMid <= 1 Integer
# 0 <= xBRUNO_PERESDMid <= 1 Integer
# 0 <= xCAICEDOAMid <= 1 Integer
# 0 <= xCALDARADLow <= 1 Integer
# 0 <= xCALHANOGLUCHig <= 1 Integer
# 0 <= xCAPUTOAHig <= 1 Integer
# 0 <= xCASTILLEJOCLow <= 1 Integer
# 0 <= xCASTROVILLICMid <= 1 Integer
# 0 <= xCHIELLINIDMid <= 1 Integer
# 0 <= xCHIESACHig <= 1 Integer
# 0 <= xCORREAAMid <= 1 Integer
# 0 <= xCRISCITODMid <= 1 Integer
# 0 <= xCUADRADODMid <= 1 Integer
# 0 <= xD'AMBROSIODHig <= 1 Integer
# 0 <= xDANILODMid <= 1 Integer
# 0 <= xDARMIANDMid <= 1 Integer
# 0 <= xDEMIRALDMid <= 1 Integer
# 0 <= xDE_LIGTDMid <= 1 Integer
# 0 <= xDE_PAULCHig <= 1 Integer
# 0 <= xDE_VRIJDMid <= 1 Integer
# 0 <= xDI_LORENZODMid <= 1 Integer
# 0 <= xDJIMSITIDMid <= 1 Integer
# 0 <= xDJURICICCMid <= 1 Integer
# 0 <= xDZEKOAMid <= 1 Integer
# 0 <= xERIKSENCMid <= 1 Integer
# 0 <= xFARAONIDMid <= 1 Integer
# 0 <= xGAGLIOLODLow <= 1 Integer
# 0 <= xGODINDLow <= 1 Integer
# 0 <= xGOSENSDHig <= 1 Integer
# 0 <= xHATEBOERDMid <= 1 Integer
# 0 <= xHERNANDEZ_T.DHig <= 1 Integer
# 0 <= xHYSAJDLow <= 1 Integer
# 0 <= xIBRAHIMOVICAHig <= 1 Integer
# 0 <= xIMMOBILEAHig <= 1 Integer
# 0 <= xINSIGNEAMid <= 1 Integer
# 0 <= xIZZODLow <= 1 Integer
# 0 <= xJANKTOCMid <= 1 Integer
# 0 <= xJOAO_PEDROAMid <= 1 Integer
# 0 <= xKESSIE'CHig <= 1 Integer
# 0 <= xKJAERDMid <= 1 Integer
# 0 <= xKOLAROVDLow <= 1 Integer
# 0 <= xKOULIBALYDLow <= 1 Integer
# 0 <= xKUCKACMid <= 1 Integer
# 0 <= xKULUSEVSKICMid <= 1 Integer
# 0 <= xKUMBULLADLow <= 1 Integer
# 0 <= xLAPADULAALow <= 1 Integer
# 0 <= xLAZOVICCMid <= 1 Integer
# 0 <= xLAZZARICMid <= 1 Integer
# 0 <= xLOCATELLICMid <= 1 Integer
# 0 <= xLOZANOAMid <= 1 Integer
# 0 <= xLUIS_ALBERTOCHig <= 1 Integer
# 0 <= xLUKAKUAHig <= 1 Integer
# 0 <= xMAKSIMOVICDLow <= 1 Integer
# 0 <= xMALCUITDLow <= 1 Integer
# 0 <= xMALINOVSKYICHig <= 1 Integer
# 0 <= xMANCINIDMid <= 1 Integer
# 0 <= xMANOLASDMid <= 1 Integer
# 0 <= xMARIO_RUIDLow <= 1 Integer
# 0 <= xMARTINEZ_L.AMid <= 1 Integer
# 0 <= xMARUSICCLow <= 1 Integer
# 0 <= xMERTENSAMid <= 1 Integer
# 0 <= xMILENKOVICDMid <= 1 Integer
# 0 <= xMILINKOVIC_SAVICCHig <= 1 Integer
# 0 <= xMKHITARYANCHig <= 1 Integer
# 0 <= xMULDURDMid <= 1 Integer
# 0 <= xMURIELAHig <= 1 Integer
# 0 <= xN'KOULOUDLow <= 1 Integer
# 0 <= xNAINGGOLANCMid <= 1 Integer
# 0 <= xNANDEZCMid <= 1 Integer
# 0 <= xORSOLINIALow <= 1 Integer
# 0 <= xPALOMINODMid <= 1 Integer
# 0 <= xPANDEVAMid <= 1 Integer
# 0 <= xPASALICCHig <= 1 Integer
# 0 <= xPELLEGRINI_LO.CMid <= 1 Integer
# 0 <= xPETAGNAAMid <= 1 Integer
# 0 <= xPEZZELLA_GER.DLow <= 1 Integer
# 0 <= xPOLITANOCMid <= 1 Integer
# 0 <= xPULGARCLow <= 1 Integer
# 0 <= xQUAGLIARELLAAMid <= 1 Integer
# 0 <= xRABIOTCLow <= 1 Integer
# 0 <= xRADUDLow <= 1 Integer
# 0 <= xRAFAEL_LEAOALow <= 1 Integer
# 0 <= xREBICAMid <= 1 Integer
# 0 <= xRODRIGUEZ_R.DLow <= 1 Integer
# 0 <= xROMERODMid <= 1 Integer
# 0 <= xRONALDOAHig <= 1 Integer
# 0 <= xRUIZCMid <= 1 Integer
# 0 <= xSAELEMAEKERSCLow <= 1 Integer
# 0 <= xSANCHEZAMid <= 1 Integer
# 0 <= xSENSICMid <= 1 Integer
# 0 <= xSKRINIARDMid <= 1 Integer
# 0 <= xSORIANOCHig <= 1 Integer
# 0 <= xSPINAZZOLADMid <= 1 Integer
# 0 <= xSTRYGER_LARSENDMid <= 1 Integer
# 0 <= xTOLOIDMid <= 1 Integer
# 0 <= xTOMIYASUDLow <= 1 Integer
# 0 <= xTRAORE'_HJ.CMid <= 1 Integer
# 0 <= xVERDICLow <= 1 Integer
# 0 <= xVERETOUTCHig <= 1 Integer
# 0 <= xYOUNGDMid <= 1 Integer
# 0 <= xZACCAGNICMid <= 1 Integer
# 0 <= xZAPATA_D.AHig <= 1 Integer
# 0 <= xZIELINSKICHig <= 1 Integer
# [xACERBIDMid,
#  xALEX_SANDRODMid,
#  xANSALDIDMid,
#  xBARELLACMid,
#  xBARROWAMid,
#  xBELOTTIAMid,
#  xBENTANCURCLow,
#  xBERARDIAHig,
#  xBERESZYNSKIDLow,
#  xBIRAGHIDMid,
#  xBOGAALow,
#  xBONAVENTURACMid,
#  xBONUCCIDMid,
#  xBREMERDMid,
#  xBROZOVICCMid,
#  xBRUNO_PERESDMid,
#  xCAICEDOAMid,
#  xCALDARADLow,
#  xCALHANOGLUCHig,
#  xCAPUTOAHig,
#  xCASTILLEJOCLow,
#  xCASTROVILLICMid,
#  xCHIELLINIDMid,
#  xCHIESACHig,
#  xCORREAAMid,
#  xCRISCITODMid,
#  xCUADRADODMid,
#  xD'AMBROSIODHig,
#  xDANILODMid,
#  xDARMIANDMid,
#  xDEMIRALDMid,
#  xDE_LIGTDMid,
#  xDE_PAULCHig,
#  xDE_VRIJDMid,
#  xDI_LORENZODMid,
#  xDJIMSITIDMid,
#  xDJURICICCMid,
#  xDZEKOAMid,
#  xERIKSENCMid,
#  xFARAONIDMid,
#  xGAGLIOLODLow,
#  xGODINDLow,
#  xGOSENSDHig,
#  xHATEBOERDMid,
#  xHERNANDEZ_T.DHig,
#  xHYSAJDLow,
#  xIBRAHIMOVICAHig,
#  xIMMOBILEAHig,
#  xINSIGNEAMid,
#  xIZZODLow,
#  xJANKTOCMid,
#  xJOAO_PEDROAMid,
#  xKESSIE'CHig,
#  xKJAERDMid,
#  xKOLAROVDLow,
#  xKOULIBALYDLow,
#  xKUCKACMid,
#  xKULUSEVSKICMid,
#  xKUMBULLADLow,
#  xLAPADULAALow,
#  xLAZOVICCMid,
#  xLAZZARICMid,
#  xLOCATELLICMid,
#  xLOZANOAMid,
#  xLUIS_ALBERTOCHig,
#  xLUKAKUAHig,
#  xMAKSIMOVICDLow,
#  xMALCUITDLow,
#  xMALINOVSKYICHig,
#  xMANCINIDMid,
#  xMANOLASDMid,
#  xMARIO_RUIDLow,
#  xMARTINEZ_L.AMid,
#  xMARUSICCLow,
#  xMERTENSAMid,
#  xMILENKOVICDMid,
#  xMILINKOVIC_SAVICCHig,
#  xMKHITARYANCHig,
#  xMULDURDMid,
#  xMURIELAHig,
#  xN'KOULOUDLow,
#  xNAINGGOLANCMid,
#  xNANDEZCMid,
#  xORSOLINIALow,
#  xPALOMINODMid,
#  xPANDEVAMid,
#  xPASALICCHig,
#  xPELLEGRINI_LO.CMid,
#  xPETAGNAAMid,
#  xPEZZELLA_GER.DLow,
#  xPOLITANOCMid,
#  xPULGARCLow,
#  xQUAGLIARELLAAMid,
#  xRABIOTCLow,
#  xRADUDLow,
#  xRAFAEL_LEAOALow,
#  xREBICAMid,
#  xRODRIGUEZ_R.DLow,
#  xROMERODMid,
#  xRONALDOAHig,
#  xRUIZCMid,
#  xSAELEMAEKERSCLow,
#  xSANCHEZAMid,
#  xSENSICMid,
#  xSKRINIARDMid,
#  xSORIANOCHig,
#  xSPINAZZOLADMid,
#  xSTRYGER_LARSENDMid,
#  xTOLOIDMid,
#  xTOMIYASUDLow,
#  xTRAORE'_HJ.CMid,
#  xVERDICLow,
#  xVERETOUTCHig,
#  xYOUNGDMid,
#  xZACCAGNICMid,
#  xZAPATA_D.AHig,
#  xZIELINSKICHig]

# %% [markdown]
# Now we are at our final stage. We will solve the problem and note each solution, both the amounts of players from each tier, and the budgets too.
#
# We iterate over the variables of the solution and clean up so we are just left with the Name of the player. This is then used to compute the budget of each A, C and D positions. After that we make variables for each tier in each position, and add that up.
#
# We are left with with the spread of players across each tier and how much budget was allocated to each position. However running this once isn't enough- we will run it numerous times and take an average solution.

# %%
optimization_result = prob.solve()


print("Status:", LpStatus[prob.status])
print("Optimal Solution to the problem: ", value(prob.objective))
print("Individual decision_variables: ")


players = []
players2 = []
Dbudget=0
Cbudget=0
Abudget=0

for i in calcio["Nome"]:

    i = i.replace(" ", "_")
    


for v in prob.variables():
    if v.varValue == 1.0:
        players.append(str(v.name)[-4:])
        players2.append(str(v.name[1:-4]))
     
                
        
for i in players2:
        
   
    if calcio.loc[calcio["Nome"] == i.replace("_", " ")].R.max() == "D":

        Dbudget += calcio["21/22_Value"].loc[calcio["Nome"] == i.replace("_", " ")].max()

    elif calcio.loc[calcio["Nome"] == i.replace("_", " ")].R.max() == "C":

        Cbudget += calcio["21/22_Value"].loc[calcio["Nome"] == i.replace("_", " ")].max()

    elif calcio.loc[calcio["Nome"] == i.replace("_", " ")].R.max() == "A":

        Abudget += calcio["21/22_Value"].loc[calcio["Nome"] == i.replace("_", " ")].max()
        
        
AHig = 0
AMid = 0
ALow = 0
CHig = 0
CMid = 0
CLow = 0
DHig = 0
DMid = 0
DLow = 0



for i in players:
    
    if i == "AHig":
        AHig += 1
    elif i == "AMid":
        AMid += 1
    elif i == "ALow":
        ALow += 1
        
    elif i == "CHig":
        CHig += 1
    elif i == "CMid":
        CMid += 1
    elif i == "CLow":
        CLow += 1

    elif i == "DHig":
        DHig += 1
    elif i == "DMid":
        DMid += 1
    elif i == "DLow":
        DLow += 1
        
print("Striker High: " + str(AHig))
print("Striker Mid: " + str(AMid))
print("Striker Low: " + str(ALow))

print("Midfielder High: " + str(CHig))
print("Midfieler Mid: " + str(CMid))
print("Midfielder Low " + str(CLow))

print("Defender High: " + str(DHig))
print("Defender Mid: " + str(DMid))
print("Defender Low " + str(DLow))

print(Dbudget)
print(Cbudget)
print(Abudget)
# Out:
# Status: Optimal
# Optimal Solution to the problem:  71.90282385
# Individual decision_variables:
# Striker High: 0
# Striker Mid: 2
# Striker Low: 1
# Midfielder High: 3
# Midfieler Mid: 0
# Midfielder Low 0
# Defender High: 3
# Defender Mid: 1
# Defender Low 0
# 135.1437838048692
# 291.5875904660068
# 272.9541150408917

# %% [markdown]
# We want to run this code numerous times so we would like to log each solution into a csv file that can later be analyzed. We will write a list including the allocations in each tier, and budget used for each position.
#
# However, we will need a .py file in order to run from the command line. The file will essentially be the same as this one, but without using the print function as we no longer need visual represantation, and commenting the printing out will enable the code to run faster. The code used to run the program 1000 times from the command line is located in the "runscript.txt" file

# %%
with open("budget.csv", "a", newline="") as csvfile:
    writer = csv.writer(csvfile)
    list = [str(AHig), str(AMid), str(ALow), str(CHig), str(CMid), str(CLow), str(DHig), str(DMid), str(DLow), str(Abudget), str(Cbudget), str(Dbudget)]
    writer.writerow(list)

# %% [markdown]
# # Conclusion & Improvements
#
# After running the code 850 times (technical difficulty), we have plenty of data to inspect. If we load up the "budget.csv" we can analyze these optimizations.
# Looking at the mode of each budget allocation, we can see that the most popular way to split the budget is the following:
#
# - Striker High: 1
# - Striker Mid: 2
# - Striker Low: 0
# - Midfielder High: 3
# - Midfielder Mid: 0
# - Midfielder Low 0
# - Defender High: 3
# - Defender Mid: 1
# - Defender Low 0
#
# We take the average of the budget allocation too:
#
# - Strikers: 387.0734682
# - Midfielders: 257.8340112
# - Defenders: 154.7775558
#
# Now we have an outline of the most economical way to spend the budget based on the types on players that are available, and it doesn't matter who the players are. This is definetly useful to us and we did infact spend our budget in a way close to this, and ended up with a good team which is currently third in the league, although our one "High" priced striker is currently injured.

# %% [markdown]
# This was certainly a good excercise in terms of optimization and I look forward to using the PuLP library more extensively in future. I will likely make some tweaks to this ahead of next season's auction and there are a few fields I am interested in improving.
#
# Firstly, I would like to explore the regression some more. Perhaps implementing a new statistical model or improving the current linear model with an exponential term for the higher end players, as this is where it seemed to struggle. More reliable player price predictions will allow us to do more advanced analysis, and also enable us to snipe deals in the live auction.
#
# Another area to improve would be to introduce more metrics for each player. Currently, we only use the data from the official site; leghe.fantacalcio.it, which gives us goals, assists, bookings and the all important player ratings. However, this doesn't include more interesting stats like expected goals (xG) and assists (xA), where we can see a player who has been previously unlucky, and might be undervalued based on what he could do. Also taking notes of minutes played and injuries would be important to gauge a players value, as a player who is often unavaialble or not selected, would be less valuable as one who averages the same rating but over more games.
